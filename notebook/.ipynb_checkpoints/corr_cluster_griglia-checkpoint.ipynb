# %%
from scipy.spatial.distance import cdist,pdist

import matplotlib.pyplot as plt
import seaborn as sns
from numpy.random import randint

# %%
import os
import sys
#SERVE PER POTER IMPORTARE I FILE .PY DALLA CARTELLA SOURCE
sys.path.append('..')
sys.path.append('..\data')


#ora src è un pacchetto e posso usare la classica dot notation di python
from src.data_load_notebook  import *
#import pandas as pd
# ||||||||||è un utilizzo un pò improprio di import, basta ricordare che così importiamo pandas
from src import classes
from src import funzioni
from src import cluster_routine
import numpy as np

# %%
picchi1 = classes.Spettri(data1,npicchi=None,prop={'height':(None,None),'prominence':1*10**-6})
picchi2 = classes.Spettri(data2,npicchi=None,prop={'height':(None,None),'prominence':1*10**-6})
picchi1.peakfinder()
picchi2.peakfinder()
pass

# %%
feat_picchi1= picchi1.featextract(cols=['peak_heights','prominences','K'],statlist=['mean','std','count'])
feat_picchi2 = picchi2.featextract(cols=['peak_heights','prominences','K'], statlist=['mean','std','count'])
km1_list= cluster_routine.km_cluster_plt(feat_picchi1, pca =3)
km2_list =  cluster_routine.km_cluster_plt(feat_picchi2, pca = 3)
feat_picchi1['labels_km']=  km1_list[1].labels_
feat_picchi2['labels_km']= km2_list[1].labels_

# %%
feat_picchi1['labels_km']=  km1_list[0].labels_
feat_picchi2['labels_km']= km2_list[3].labels_

# %%
l = [(x,y) for x in range(1,12) for y in range(1,12)]
grid = np.array(l).astype(float)
plt.xlim(0,14)
plt.ylim(0,14)
fig = plt.gcf()
fig.set_size_inches(11, 7)
sns.scatterplot(x = grid[:,0], y = grid[:,1], hue = feat_picchi2['labels_km'])
np.unique(feat_picchi1['labels_km'],return_counts = True)

# %%
feat_picchi1= picchi1.featextract(cols=['peak_heights','prominences','K'],statlist=['mean','std','count'])
feat_picchi2 = picchi2.featextract(cols=['peak_heights','prominences','K'], statlist=['mean','std','count'])
db1list = cluster_routine.db_cluster_plt(feat_picchi1,n_components=2, eps= 0.3, min_samples=5)
# Out:
# con eps =  0.24 abbiamo (array([-1,  0,  1,  2,  3], dtype=int64), array([71, 33,  6,  5,  6], dtype=int64)) clusters e lo score : -0.060571638688169976
# con eps =  0.2533333333333333 abbiamo (array([-1,  0,  1,  2,  3], dtype=int64), array([67, 33, 10,  5,  6], dtype=int64)) clusters e lo score : -0.02778284427964119
# con eps =  0.26666666666666666 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([61, 45,  9,  6], dtype=int64)) clusters e lo score : 0.026846502908736088
# con eps =  0.27999999999999997 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([55, 50, 10,  6], dtype=int64)) clusters e lo score : 0.05633493030490182
# con eps =  0.29333333333333333 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([54, 51,  6, 10], dtype=int64)) clusters e lo score : 0.06063763832186406
# con eps =  0.30666666666666664 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([52, 52,  6, 11], dtype=int64)) clusters e lo score : 0.07773214986865035
# con eps =  0.31999999999999995 abbiamo (array([-1,  0,  1,  2,  3], dtype=int64), array([47, 52,  6, 11,  5], dtype=int64)) clusters e lo score : 0.05743873684272628
# con eps =  0.3333333333333333 abbiamo (array([-1,  0,  1,  2,  3], dtype=int64), array([41, 58,  6, 11,  5], dtype=int64)) clusters e lo score : 0.05170346075293217
# con eps =  0.3466666666666667 abbiamo (array([-1,  0,  1,  2,  3], dtype=int64), array([36, 63,  6, 11,  5], dtype=int64)) clusters e lo score : 0.0543346413919065
# con eps =  0.36 abbiamo (array([-1,  0,  1,  2,  3], dtype=int64), array([34, 65,  6, 11,  5], dtype=int64)) clusters e lo score : 0.05591632307527132

# %%
feat_picchi1['labels_db'] = db1list[-2].labels_
funzioni.distpoint(feat_picchi1['labels_db'])
for lab in np.unique(feat_picchi1è'labels_db'):
    print({''})
# Out:
# C:\Users\Utente\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
db2list = cluster_routine.db_cluster_plt(feat_picchi2)
# Out:
# con eps =  0.24 abbiamo (array([-1,  0,  1], dtype=int64), array([48, 66,  7], dtype=int64)) clusters e lo score : 0.16261448678228796
# con eps =  0.2533333333333333 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([43, 66,  7,  5], dtype=int64)) clusters e lo score : 0.1612939209263729
# con eps =  0.26666666666666666 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([40, 69,  7,  5], dtype=int64)) clusters e lo score : 0.17044775424572894
# con eps =  0.27999999999999997 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([38, 70,  7,  6], dtype=int64)) clusters e lo score : 0.1896319464913006
# con eps =  0.29333333333333333 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([38, 70,  7,  6], dtype=int64)) clusters e lo score : 0.1896319464913006
# con eps =  0.30666666666666664 abbiamo (array([-1,  0,  1,  2], dtype=int64), array([35, 71,  7,  8], dtype=int64)) clusters e lo score : 0.2242609157242282
# con eps =  0.31999999999999995 abbiamo (array([-1,  0,  1], dtype=int64), array([34, 80,  7], dtype=int64)) clusters e lo score : 0.20685989065255228
# con eps =  0.3333333333333333 abbiamo (array([-1,  0,  1], dtype=int64), array([34, 80,  7], dtype=int64)) clusters e lo score : 0.20685989065255228
# con eps =  0.3466666666666667 abbiamo (array([-1,  0,  1], dtype=int64), array([34, 80,  7], dtype=int64)) clusters e lo score : 0.20685989065255228
# con eps =  0.36 abbiamo (array([-1,  0,  1], dtype=int64), array([33, 81,  7], dtype=int64)) clusters e lo score : 0.20630996028337734

# %%
feat_picchi1['labels_db'] = db1list[4].labels_
funzioni.distpoint(feat_picchi1['labels_db'])
# Out:
# C:\Users\Utente\miniconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
funzioni.index_translate(feat_picchi1[feat_picchi1['labels_db']==0].index)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 1>()
# ----> 1 funzioni.index_translate(feat_picchi1[feat_picchi1['labels_db']==0].index)
#
# AttributeError: module 'src.funzioni' has no attribute 'index_translate'
