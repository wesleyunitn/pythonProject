# %% [markdown]
# # Training e prime valutazioni
#
# Notebook esplorativo del training

# %%
import os
import sys
#SERVE PER POTER IMPORTARE I FILE .PY DALLA CARTELLA SOURCE
sys.path.append('..')
sys.path.append('..\data')
sys.path.append('..\src')
# importo i miei script dal package src
from data_load_notebook  import *
#import pandas as pd|
# ||||||||||è un utilizzo un pò improprio di import, basta ricordare che così importiamo pandas
from classes import Spettri,plot_peaks, plot_spettri
import funzioni
import cluster_routine
import numpy as np
import Training

from data_load import *
from classes import Spettri,plot_spettri,plot_peaks
import labelling
from sklearn.model_selection import GridSearchCV, StratifiedKFold, StratifiedShuffleSplit
from sklearn.pipeline import Pipeline
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, f1_score,make_scorer, matthews_corrcoef
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier



import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

pass
# Out:
# picchi: 10  proprietà di ricerca : {'height': (None, None), 'prominence': (None, None), 'width': (None, None), 'wlen': 150}

# %%
len()

# %%
#routine per estrarre i picchi e le feature dai csampioni
pk1 = Spettri(data1)
pk2 = Spettri(data2)
pk1.go()
pk2.go()
lab1_ = load_data('.\pk1_scaled\labels')
lab2_ = load_data('.\pk2_scaled\labels')
pass

# %% [markdown]
# ## feature 1
#
# Mi focalizzo su uno spazio alla volta, la funzionie **train_gsearch**
# devo fare solo la pipeline con la griglia di parametri desiderata

# %%
#
scoringf1 = make_scorer(f1_score, average='weighted')
matt_score = make_scorer(matthews_corrcoef)

log_reg = LogisticRegression(random_state= 100, multi_class='ovr', solver = 'saga', class_weight='balanced',max_iter=1500)
steps= [('scaler',StandardScaler()),('pca',PCA()),('log_reg',log_reg)]
param_g = {'pca__n_components': [2,4,6,8],'log_reg__C': [1,1.1,1.2,0.9,1.4]}
skfold = StratifiedKFold(n_splits=3, random_state=1223, shuffle=True)
pipekm = Pipeline(steps)
ypk1_feat1 = np.array(lab1_ )
gsearch_pk1_feat1,right_material_11 = Training.train_gridsearch(pipekm,pk1.feature,ypk1_feat1, cv = None, scoring = matt_score,param_grid = param_g)
gsearch_pk1_feat1.best_score_

# %%
scoringf1 = make_scorer(f1_score, average='weighted')
matt_score = make_scorer(matthews_corrcoef)

log_reg = LogisticRegression(random_state= 100, multi_class='ovr', solver = 'saga', class_weight='balanced',max_iter=1500)
steps= [('scaler',StandardScaler()),('pca',PCA()),('log_reg',log_reg)]
param_g = {'pca__n_components': [2,4,6,8],'log_reg__C': [1,1.1,1.2,0.9,1.4]}
skfold = StratifiedKFold(n_splits=3, random_state=1223, shuffle=True)
pipekm = Pipeline(steps)
ypk1_feat1 = np.array(lab1_ )
gsearch_pk1_feat1,right_material_11 = Training.train_gridsearch(pipekm,pk1.feature,ypk1_feat1, cv = None, exclude_single=True, scoring = matt_score,param_grid = param_g)
gsearch_pk1_feat1.best_score_
# Out:
# C:\Users\Utente\miniconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(
# C:\Users\Utente\miniconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Utente\miniconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Utente\miniconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# C:\Users\Utente\miniconda3\lib\site-packages\sklearn\linear_model\_sag.py:352: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# ...

# %%
log_reg2 = LogisticRegression(random_state= 100, multi_class='ovr', solver = 'saga', class_weight='balanced',max_iter=400)
steps= [('scaler',StandardScaler()),('pca',PCA()),('log_reg',log_reg)]
param_g2 = {'pca__n_components': [2,4,6,8],'log_reg__C': [1,1.1,1.2,0.9,1.4]}
skfold = StratifiedKFold(n_splits=4, random_state=1223, shuffle=True)
pipekm2 = Pipeline(steps)
ypk2_feat1 = np.array(lab1_ )

gsearch_pk12, right_mat12 = Training.train_gridsearch(pipekm2,pk1.feature2,ypk1_feat1,cv = skfold, param_grid = param_g)

# %%
feat1transf = pd.DataFrame(search.best_estimator_[:-1].transform(pk1.feature))
feat1transf['labels']= search.best_estimator_.predict(pk1.feature)
plt.figure(figsize = (17,8))
sns.scatterplot(data = feat1transf,x = 0, y = 1, hue= 'labels')

# %%
lab = search.best_estimator_.predict(database_feat1)
databasetranform = pd.DataFrame(search.best_estimator_[:-1].fit_transform(database_feat1))
databasetranform['labels'] = lab
plt.figure(figsize = (17,8))
sns.scatterplot(data = databasetranform, x = 0, y = 1, hue = 'labels')

# %%
gsearch_pk12_feat1(0).bes
